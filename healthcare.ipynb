# %%
import pandas as pd
pd
# Out:
# <module 'pandas' from 'c:\\Users\\mrcha\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df=pd.read_csv(r"C:\Users\mrcha\Documents\Data Scientist\Projects\healthcare_noshows.csv")
df
# Out:
#            PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0       2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1       5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2       4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3       8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4       8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
# ...              ...            ...    ...          ...            ...  ...
# 106982  2.572134e+12        5651768      F   2016-05-03     2016-06-07   56
# 106983  3.596266e+12        5650093      F   2016-05-03     2016-06-07   51
# 106984  1.557663e+13        5630692      F   2016-04-27     2016-06-07   21
# 106985  9.213493e+13        5630323      F   2016-04-27     2016-06-07   38
# 106986  3.775115e+14        5629448      F   2016-04-27     2016-06-07   54
#
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#            PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0       2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1       5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2       4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3       8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4       8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
# ...              ...            ...    ...          ...            ...  ...
# 106982  2.572134e+12        5651768      F   2016-05-03     2016-06-07   56
# 106983  3.596266e+12        5650093      F   2016-05-03     2016-06-07   51
# 106984  1.557663e+13        5630692      F   2016-04-27     2016-06-07   21
# 106985  9.213493e+13        5630323      F   2016-04-27     2016-06-07   38
# 106986  3.775115e+14        5629448      F   2016-04-27     2016-06-07   54
#
# ...

# %%
df2=df['Gender'] = df['Gender'].str.replace('M',"Male")

# %%
df2=df['Gender'] = df['Gender'].str.replace('F',"Female")

# %%
df3=df[df['Age']<18]

# %%
df4=df[(df['Age']>18) & (df['Age']<30)]

# %%
df4
# Out:
#            PatientId  AppointmentID  Gender ScheduledDay AppointmentDay  Age  \
# 6       7.336882e+14        5630279  Female   2016-04-27     2016-04-29   23
# 8       5.639473e+13        5638447  Female   2016-04-29     2016-04-29   21
# 9       7.812456e+13        5629123  Female   2016-04-27     2016-04-29   19
# 11      7.542951e+12        5620163    Male   2016-04-26     2016-04-29   29
# 12      5.666548e+14        5634718  Female   2016-04-28     2016-04-29   22
# ...              ...            ...     ...          ...            ...  ...
# 106954  1.712135e+11        5788054    Male   2016-06-08     2016-06-08   21
# 106963  7.316229e+14        5787937  Female   2016-06-08     2016-06-08   22
# 106977  5.574942e+12        5780122  Female   2016-06-07     2016-06-07   19
# 106979  6.542388e+13        5630447  Female   2016-04-27     2016-06-07   22
# 106984  1.557663e+13        5630692  Female   2016-04-27     2016-06-07   21
#
# ...

# %%
len(df)
# Out:
# 106987

# %%
df.count()
# Out:
# PatientId         106987
# AppointmentID     106987
# Gender            106987
# ScheduledDay      106987
# AppointmentDay    106987
# Age               106987
# Neighbourhood     106987
# Scholarship       106987
# Hipertension      106987
# Diabetes          106987
# Alcoholism        106987
# Handcap           106987
# SMS_received      106987
# Showed_up         106987
# Date.diff         106987
# dtype: int64

# %%
df.tail()
# Out:
#            PatientId  AppointmentID  Gender ScheduledDay AppointmentDay  Age  \
# 106982  2.572134e+12        5651768  Female   2016-05-03     2016-06-07   56
# 106983  3.596266e+12        5650093  Female   2016-05-03     2016-06-07   51
# 106984  1.557663e+13        5630692  Female   2016-04-27     2016-06-07   21
# 106985  9.213493e+13        5630323  Female   2016-04-27     2016-06-07   38
# 106986  3.775115e+14        5629448  Female   2016-04-27     2016-06-07   54
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 106982   MARIA ORTIZ        False         False     False       False
# 106983   MARIA ORTIZ        False         False     False       False
# 106984   MARIA ORTIZ        False         False     False       False
# 106985   MARIA ORTIZ        False         False     False       False
# 106986   MARIA ORTIZ        False         False     False       False
#
#         Handcap  SMS_received  Showed_up  Date.diff
# ...

# %%
df5= df["PatientId"]=df["PatientId"].astype(int)

# %%
print(df)
# Out:
#               PatientId  AppointmentID  Gender ScheduledDay AppointmentDay  \
# 0        29872499824296        5642903  Female   2016-04-29     2016-04-29
# 1       558997776694438        5642503    Male   2016-04-29     2016-04-29
# 2         4262962299951        5642549  Female   2016-04-29     2016-04-29
# 3          867951213174        5642828  Female   2016-04-29     2016-04-29
# 4         8841186448183        5642494  Female   2016-04-29     2016-04-29
# ...                 ...            ...     ...          ...            ...
# 106982    2572134369293        5651768  Female   2016-05-03     2016-06-07
# 106983    3596266328735        5650093  Female   2016-05-03     2016-06-07
# 106984   15576631729893        5630692  Female   2016-04-27     2016-06-07
# 106985   92134931435557        5630323  Female   2016-04-27     2016-06-07
# 106986  377511518121127        5629448  Female   2016-04-27     2016-06-07
#
# ...

# %%
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
df.head()
# Out:
#          PatientId  AppointmentID  Gender ScheduledDay AppointmentDay  Age  \
# 0   29872499824296        5642903  Female   2016-04-29     2016-04-29   62
# 1  558997776694438        5642503    Male   2016-04-29     2016-04-29   56
# 2    4262962299951        5642549  Female   2016-04-29     2016-04-29   62
# 3     867951213174        5642828  Female   2016-04-29     2016-04-29    8
# 4    8841186448183        5642494  Female   2016-04-29     2016-04-29   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA        False          True     False       False
# 1    JARDIM DA PENHA        False         False     False       False
# 2      MATA DA PRAIA        False         False     False       False
# 3  PONTAL DE CAMBURI        False         False     False       False
# 4    JARDIM DA PENHA        False          True      True       False
#
#    Handcap  SMS_received  Showed_up  Date.diff
# ...

# %%
a=np.array(df.Gender)
b=np.array(df.Age <18)

# %%
plt.plot()

# %%
import matplotlib.pyplot as plt

# %%
df.shape
# Out:
# (106987, 15)

# %%
df.tail()
# Out:
#               PatientId  AppointmentID  Gender ScheduledDay AppointmentDay  \
# 106982    2572134369293        5651768  Female   2016-05-03     2016-06-07
# 106983    3596266328735        5650093  Female   2016-05-03     2016-06-07
# 106984   15576631729893        5630692  Female   2016-04-27     2016-06-07
# 106985   92134931435557        5630323  Female   2016-04-27     2016-06-07
# 106986  377511518121127        5629448  Female   2016-04-27     2016-06-07
#
#         Age Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 106982   56   MARIA ORTIZ        False         False     False       False
# 106983   51   MARIA ORTIZ        False         False     False       False
# 106984   21   MARIA ORTIZ        False         False     False       False
# 106985   38   MARIA ORTIZ        False         False     False       False
# 106986   54   MARIA ORTIZ        False         False     False       False
#
#         Handcap  SMS_received  Showed_up  Date.diff
# ...

# %%
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# Showed_up         0
# Date.diff         0
# dtype: int64

# %%
df['AppointmentDay'].value_counts()
# Out:
# AppointmentDay
# 2016-06-06    4528
# 2016-05-16    4449
# 2016-05-30    4360
# 2016-06-08    4356
# 2016-05-09    4352
# 2016-06-01    4351
# 2016-05-11    4347
# 2016-06-07    4264
# 2016-05-12    4233
# 2016-05-17    4227
# 2016-05-18    4220
# 2016-05-02    4214
# 2016-06-02    4204
# 2016-05-10    4177
# 2016-05-31    4158
# 2016-05-03    4129
# 2016-05-05    4113
# 2016-05-19    4109
# 2016-05-04    4048
# 2016-06-03    3978
# 2016-05-13    3885
# 2016-05-24    3876
# 2016-05-06    3791
# 2016-05-25    3768
# 2016-05-20    3707
# 2016-04-29    3104
# 2016-05-14      39
# Name: count, dtype: int64

# %%
df['Scholarship'].value_counts()
# Out:
# Scholarship
# False    96178
# True     10809
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12
                    ,6))
sns.countplot(x='Gender',data=df)
plt.savefig("Gender.jpg")
plt.show()

# %%
df.head()
# Out:
#          PatientId  AppointmentID  Gender ScheduledDay AppointmentDay  Age  \
# 0   29872499824296        5642903  Female   2016-04-29     2016-04-29   62
# 1  558997776694438        5642503    Male   2016-04-29     2016-04-29   56
# 2    4262962299951        5642549  Female   2016-04-29     2016-04-29   62
# 3     867951213174        5642828  Female   2016-04-29     2016-04-29    8
# 4    8841186448183        5642494  Female   2016-04-29     2016-04-29   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA        False          True     False       False
# 1    JARDIM DA PENHA        False         False     False       False
# 2      MATA DA PRAIA        False         False     False       False
# 3  PONTAL DE CAMBURI        False         False     False       False
# 4    JARDIM DA PENHA        False          True      True       False
#
#    Handcap  SMS_received  Showed_up  Date.diff
# ...

# %%
def categorize_age(a):
    if a > 60:
        return 'Senior Citizens >60'
    elif a > 23:
        return 'Citizens >23'
    elif a >= 18:
        return 'Adults >=18'
    elif a >= 10:
        return 'Minors <18'
    elif a < 10:
        return 'Kids <10'
    else:
        return 'NA'

df["Category"] = df["Age"].apply(categorize_age)

# %%
plt.figure(figsize=(5,6))
sns.countplot( x='Gender',data=df)
plt.show()
# plt.figure(figsize=(6,5))
# sns.countplot(x='Gender',data=df, color='green')
# plt.title("Gender Identification")
# plt.savefig("Gender.jpg")
# plt.show()

# %%
df.head()
# Out:
#          PatientId  AppointmentID  Gender ScheduledDay AppointmentDay  Age  \
# 0   29872499824296        5642903  Female   2016-04-29     2016-04-29   62
# 1  558997776694438        5642503    Male   2016-04-29     2016-04-29   56
# 2    4262962299951        5642549  Female   2016-04-29     2016-04-29   62
# 3     867951213174        5642828  Female   2016-04-29     2016-04-29    8
# 4    8841186448183        5642494  Female   2016-04-29     2016-04-29   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA        False          True     False       False
# 1    JARDIM DA PENHA        False         False     False       False
# 2      MATA DA PRAIA        False         False     False       False
# 3  PONTAL DE CAMBURI        False         False     False       False
# 4    JARDIM DA PENHA        False          True      True       False
#
#    Handcap  SMS_received  Showed_up  Date.diff         Category
# ...

# %%
df['Date.diff'].value_counts()
# Out:
# Date.diff
#  0      37154
#  2       6636
#  4       5212
#  1       5028
#  7       4785
#         ...
# -6          1
#  132        1
#  117        1
#  146        1
#  123        1
# Name: count, Length: 131, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='',data=df)
plt.title("Benifits determination")
# plt.savefig("Category.jpg")
plt.bar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[154], line 5
#       3 plt.title("Benifits determination")
#       4 # plt.savefig("Category.jpg")
# ----> 5 plt.bar()
#       6 plt.show()
#
# TypeError: bar() missing 2 required positional arguments: 'x' and 'height'

# %%
plt.figure(figsize=(5, 5))
df['Alcoholism'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set3"))
plt.title("Alcoholism")
plt.savefig('Alcoholism.jpg')
plt.ylabel('')  # Hides the y-label
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Scholarship'], bins=10, kde=False)
plt.title("Benefits Determination - Histogram")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Scholarship'], bins=10, kde=False)
plt.title("Benefits Determination - Histogram")
plt.savefig('Scholarship.jpg')
plt.show()

# %%
df['Category'].value_counts()
# Out:
# Category
# Citizens           54739
# Senior Citizens    19762
# Kids               13936
# Minors              9904
# Adults              8646
# Name: count, dtype: int64

# %%
x=df['Category'].value_counts().index
y=df['Category'].value_counts().values

# %%
plt.figure(figsize=(5,5))
plt.pie(y,labels=x,startangle=60, autopct='%0.2f%%')
plt.title("Category Analysis")
plt.savefig('Category Analysis.jpg')
plt.show()
