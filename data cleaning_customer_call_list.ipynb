# %%
import pandas as pd
df =pd.read_excel(r"C:\Users\mrcha\Documents\Data Scientist\Projects\alex-the-analyst\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df6=df.drop(columns='Not_Useful_Column')  # removig the Not_Useful_Column

# %%
df=df.drop_duplicates  # Deleting the duplicates in Data Frame

# %%
df3=df['Phone_Number'].str.replace('|','',regex=False)   # cleaning the special character (|) in the Phone_Number column

# %%
df3
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2              NaN
# 3     123-543-2345
# 4       8766783469
# 5     304-762-2467
# 6              NaN
# 7       8766783469
# 8              N/a
# 9     123-545-5421
# 10             NaN
# 11             NaN
# 12    123-543-2345
# 13      8766783469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17             NaN
# 18             N/a
# 19      8766783469
# 20      8766783469
# Name: Phone_Number, dtype: object

# %%
df3=df['Phone_Number']=df['Phone_Number'].str.replace('-','',regex=True) # cleaning the special character (-) in the Phone_Number column

# %%
df3=df['Phone_Number']=df['Phone_Number'].str.replace('|','',regex=False) # cleaning the special character (|) in the Phone_Number column

# %%
df3=df['Phone_Number']=df['Phone_Number'].str.replace('/','',regex=False) # cleaning the special character (/) in the Phone_Number column

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 2         1003     Walter       /White          NaN
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 6         1007       Jeff       Winger          NaN
# 7         1008   Sherlock       Holmes   8766783469
# 8         1009    Gandalf          NaN           Na
# 9         1010      Peter       Parker   1235455421
# 10        1011    Samwise       Gamgee          NaN
# 11        1012      Harry    ...Potter          NaN
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# ...

# %%
df3=df['Last_Name']=df['Last_Name'].str.replace('/','',regex=False) # cleaning the special character (/) in the Last_Name column

# %%
df3=df['Last_Name']=df['Last_Name'].str.replace('...','',regex=False)  # cleaning the special character (...) in the Last_Name column

# %%
df3=df['Last_Name']=df['Last_Name'].str.replace('_','',regex=False) # cleaning the special character (_) in the Last_Name column

# %%
df4=df[['City','State','ZIP']]=df['Address'].str.split(',',n=2, expand=True) # Splitting the Address column  into three column like ('City','state','ZIP')

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name Phone_Number  \
# 0        1001      Frodo   Baggins   1235455421
# 1        1002       Abed     Nadir   1236439775
# 2        1003     Walter     White          NaN
# 3        1004     Dwight   Schrute   1235432345
# 4        1005        Jon      Snow   8766783469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column                 City          State     ZIP
# 0               True       123 Shire Lane          Shire    None
# 1              False  93 West Main Street           None    None
# ...

# %%
df=df.drop(columns='Address') # deleting the Address column in the DataFrame

# %%
df5=df['Paying Customer']=df['Paying Customer'].str.replace('Yes','Y',regex=False)   # Replacing the vale of Yes to Y in the Paying Customer column.
# df['Paying Customer'].str.replace('Yes','Y', regex=False)

# %%
df5=df['Paying Customer']=df['Paying Customer'].str.replace('No','N',regex=False) # Replacing the vale of No to N in the Paying Customer column.

# %%
df5
# Out:
# 0       Y
# 1       N
# 2       N
# 3       Y
# 4       Y
# 5       Y
# 6       N
# 7       N
# 8       Y
# 9       Y
# 10      Y
# 11      Y
# 12      Y
# 13      Y
# 14      N
# 15      N
# 16      Y
# 17      Y
# 18    N/a
# 19      Y
# 20      Y
# Name: Paying Customer, dtype: object

# %%
df6=df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('No','N',regex=False) # Replacing the vale of Yes to Y in the Do_Not_Contact column.

# %%
df6=df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('Yes','Y',regex=False) # Replacing the vale of No to N in the Do_Not_Contact column.

# %%
df7=df

# %%
df7
# Out:
# <bound method DataFrame.drop_duplicates of     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421               Y
# 1         1002       Abed       Nadir   1236439775               N
# 2         1003     Walter       White          NaN               N
# 3         1004     Dwight     Schrute   1235432345               Y
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467               Y
# 6         1007       Jeff      Winger          NaN               N
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf         NaN           Na               Y
# 9         1010      Peter      Parker   1235455421               Y
# 10        1011    Samwise      Gamgee          NaN               Y
# 11        1012      Harry      Potter          NaN               Y
# ...
